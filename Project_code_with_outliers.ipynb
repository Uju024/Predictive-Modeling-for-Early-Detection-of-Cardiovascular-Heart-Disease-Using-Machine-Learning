# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User'

# %%
os.chdir('C:\\Users\\User\\OneDrive\\Desktop\\Project_Module_7150CEM')

# %%
# importing libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import scipy as sp
import sklearn
import seaborn as sns

# %%
# import dataset

data = pd.read_csv('Dataset.of.Heart.csv')

# %%
data
# Out:
#      age     sex               cp  trtbps  chol    fbs      rest_ecg  \
# 0     63    Male     Asymptomatic     145   233   True        Normal
# 1     37    Male  Atypical Angina     130   250  False  ST Elevation
# 2     41  Female   Typical Angina     130   204  False        Normal
# 3     56    Male   Typical Angina     120   236  False  ST Elevation
# 4     57  Female       Non-Angina     120   354  False  ST Elevation
# ..   ...     ...              ...     ...   ...    ...           ...
# 298   57  Female       Non-Angina     140   241  False  ST Elevation
# 299   45    Male     Asymptomatic     110   264  False  ST Elevation
# 300   68    Male       Non-Angina     144   193   True  ST Elevation
# 301   57    Male       Non-Angina     130   131  False  ST Elevation
# 302   57  Female   Typical Angina     130   236  False        Normal
#
#      thalachh exng  oldpeak       slope  ca  thall  target
# 0         150   No      2.3        Flat   0      1       1
# ...

# %% [markdown]
# ## Exploratory Data Analysis
# ### Exploring the data

# %%
print(data.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'rest_ecg', 'thalachh',
#        'exng', 'oldpeak', 'slope', 'ca', 'thall', 'target'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    object
#  2   cp        303 non-null    object
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    bool
#  6   rest_ecg  303 non-null    object
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    object
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    object
#  11  ca        303 non-null    int64
#  12  thall     303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: bool(1), float64(1), int64(7), object(5)
# memory usage: 31.2+ KB

# %%
# categorical variable: sex, cp, rest_ecg, exng, slope, fbs.
# numerical variables: age, trtbps, chol, thalach, oldpeak, ca, thall.

# %%
data.shape
# Out:
# (303, 14)

# %%
data.ndim
# Out:
# 2

# %%
data.head()
# Out:
#    age     sex               cp  trtbps  chol    fbs      rest_ecg  thalachh  \
# 0   63    Male     Asymptomatic     145   233   True        Normal       150
# 1   37    Male  Atypical Angina     130   250  False  ST Elevation       187
# 2   41  Female   Typical Angina     130   204  False        Normal       172
# 3   56    Male   Typical Angina     120   236  False  ST Elevation       178
# 4   57  Female       Non-Angina     120   354  False  ST Elevation       163
#
#   exng  oldpeak       slope  ca  thall  target
# 0   No      2.3        Flat   0      1       1
# 1   No      3.5  Up Sloping   0      2       1
# 2   No      1.4        Flat   0      2       1
# 3   No      0.8        Flat   0      2       1
# 4  Yes      0.6        Flat   0      2       1

# %%
data.tail()
# Out:
#      age     sex              cp  trtbps  chol    fbs      rest_ecg  thalachh  \
# 298   57  Female      Non-Angina     140   241  False  ST Elevation       123
# 299   45    Male    Asymptomatic     110   264  False  ST Elevation       132
# 300   68    Male      Non-Angina     144   193   True  ST Elevation       141
# 301   57    Male      Non-Angina     130   131  False  ST Elevation       115
# 302   57  Female  Typical Angina     130   236  False        Normal       174
#
#     exng  oldpeak       slope  ca  thall  target
# 298  Yes      0.2  Up Sloping   0      3       0
# 299   No      1.2  Up Sloping   0      3       0
# 300   No      3.4  Up Sloping   2      3       0
# 301  Yes      1.2  Up Sloping   1      3       0
# 302   No      0.0  Up Sloping   1      2       0

# %%
data.describe()
# Out:
#               age      trtbps        chol    thalachh     oldpeak          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337  131.623762  246.264026  149.646865    1.039604    0.709571
# std      9.082101   17.538143   51.830751   22.905161    1.161075    0.970496
# min     29.000000   94.000000  126.000000   71.000000    0.000000    0.000000
# 25%     47.500000  120.000000  211.000000  133.500000    0.000000    0.000000
# 50%     55.000000  130.000000  240.000000  153.000000    0.800000    0.000000
# 75%     61.000000  140.000000  274.500000  166.000000    1.600000    1.000000
# max     77.000000  200.000000  564.000000  202.000000    6.200000    3.000000
#
#             thall      target
# count  303.000000  303.000000
# mean     2.323432    0.544554
# std      0.587687    0.498835
# min      1.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# ...

# %% [markdown]
# #### Checking for unique values

# %%
print(len(data.sex.unique()))
print(data.sex.unique())
# Out:
# 2
# ['Male' 'Female']

# %%
print(len(data.cp.unique()))
print(data.cp.unique())
# Out:
# 4
# ['Asymptomatic' 'Atypical Angina' 'Typical Angina' 'Non-Angina']

# %%
print(len(data.fbs.unique()))
print(data.fbs.unique())
# Out:
# 2
# [ True False]

# %%
print(len(data.rest_ecg.unique()))
print(data.rest_ecg.unique())
# Out:
# 3
# ['Normal' 'ST Elevation' 'Left Ventricular Hypertrophy']

# %%
print(len(data.exng.unique()))
print(data.exng.unique())
# Out:
# 2
# ['No' 'Yes']

# %%
print(len(data.slope.unique()))
print(data.slope.unique())
# Out:
# 3
# ['Flat' 'Up Sloping' 'Down Sloping']

# %%
print(len(data.ca.unique()))
print(data.ca.unique())
# Out:
# 4
# [0 2 1 3]

# %%
print(len(data.thall.unique()))
print(data.thall.unique())
# Out:
# 3
# [1 2 3]

# %%
print(len(data.target.unique()))
print(data.target.unique())
# Out:
# 2
# [1 0]

# %%
# checking the number of classes we have in the target variable and if the classes are balanced

#data.target.value_counts()

Target = data['target'] # target variable
class_counts = data['target'].value_counts()
print(class_counts)

plt.figure(figsize=(8,6))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Class balance check')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64
# Text(0, 0.5, 'Count')

# %%
# checking for missing values in the data

data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# rest_ecg    0
# thalachh    0
# exng        0
# oldpeak     0
# slope       0
# ca          0
# thall       0
# target      0
# dtype: int64

# %% [markdown]
# ### Distribution plots for each variables

# %%
sns.histplot(data = data, x= 'age', hue = 'target', multiple='stack')
plt.title('Age and CVD Distribution')
plt.show()

sns.boxplot(data=data, x='target', y='age', hue = 'target')
plt.title('Age and CVD Distribution')
plt.show()

# %%
sns.histplot(data = data, x= 'trtbps', hue = 'target', multiple='stack')
plt.title('Resting Blood Pressure and CVD Distribution')
plt.show()


sns.boxplot(data=data, x='target', y='trtbps', hue = 'target')
plt.title('Resting Blood Pressure and CVD Distribution')
plt.show()

# %%
sns.histplot(data = data, x= 'chol', hue = 'target', multiple='stack')
plt.title('Cholestorol and CVD Distribution')
plt.show()


sns.boxplot(data=data, x='target', y='chol', hue = 'target')
plt.title('Cholestorol and CVD Distribution')
plt.show()

# %%
sns.histplot(data = data, x= 'thalachh', hue = 'target', multiple='stack')
plt.title('Maximum Heart Rate and CVD Distribution')
plt.show()


sns.boxplot(data=data, x='target', y='thalachh', hue = 'target')
plt.title('Maximum Heart rate and CVD Distribution')
plt.show()

# %%
sns.histplot(data = data, x= 'oldpeak', hue = 'target', multiple='stack')
plt.title('Exercise induced ST Depression and CVD Distribution')
plt.show()


sns.boxplot(data=data, x='target', y='oldpeak', hue = 'target')
plt.title('Exercise induced ST Depression and CVD Distribution')
plt.show()

# %%
from matplotlib.patches import Patch



# Calculate the counts of each category
summary = data.groupby(['sex', 'target']).size().unstack(fill_value=0)
summary.columns = ['No Disease', 'Heart Disease']

# Calculate the percentages
summary['Total'] = summary.sum(axis=1)
summary['Heart Disease %'] = (summary['Heart Disease'] / summary['Total']) * 100
summary['No Disease %'] = (summary['No Disease'] / summary['Total']) * 100

# Prepare data for plotting
plot_data = pd.DataFrame({
    'Condition': ['Heart Disease', 'No Disease', 'Heart Disease', 'No Disease'],
    'Percentage': [
        summary.loc['Male', 'Heart Disease %'],
        summary.loc['Male', 'No Disease %'],
        summary.loc['Female', 'Heart Disease %'],
        summary.loc['Female', 'No Disease %']
    ],
    'Sex': ['Male', 'Male', 'Female', 'Female']
})

# Plotting the data
fig, ax = plt.subplots()

# Plot the bars
colors = {'Male': 'orange', 'Female': 'blue'}
bars = ax.bar(plot_data['Condition'] + ' (' + plot_data['Sex'] + ')', plot_data['Percentage'], color=[colors[sex] for sex in plot_data['Sex']])

# Adding annotations
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.1f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# Setting the title and labels
ax.set_title('Prevalence of Heart Disease among Men and Women')
ax.set_xlabel('Condition')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
ax.set_ylabel('Percentage')
ax.set_ylim(0, 100)
# Add legend
# Add custom legend
legend_elements = [Patch(facecolor='orange', label='Male'),
                   Patch(facecolor='blue', label='Female')]
ax.legend(handles=legend_elements, title='Sex')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Matrix between all the variables

# %%
plt.figure(figsize=(13,7))
sns.heatmap(data.corr(), vmin=-1, vmax=1, cmap=None, annot=True)
plt.title('Correlation matrix between all the variables', fontsize = 20)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_39680\3951107377.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), vmin=-1, vmax=1, cmap=None, annot=True)

# %% [markdown]
# ## Label Encoding to change categorical variables to numerical variables

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label = LabelEncoder()

# Encode categorical columns
for col in ['sex', 'cp', 'rest_ecg', 'exng', 'slope', 'fbs']:
    data[col] = label.fit_transform(data[col])

# %%
data.head
# Out:
# <bound method NDFrame.head of      age  sex  cp  trtbps  chol  fbs  rest_ecg  thalachh  exng  oldpeak  \
# 0     63    1   0     145   233    1         1       150     0      2.3
# 1     37    1   1     130   250    0         2       187     0      3.5
# 2     41    0   3     130   204    0         1       172     0      1.4
# 3     56    1   3     120   236    0         2       178     0      0.8
# 4     57    0   2     120   354    0         2       163     1      0.6
# ..   ...  ...  ..     ...   ...  ...       ...       ...   ...      ...
# 298   57    0   2     140   241    0         2       123     1      0.2
# 299   45    1   0     110   264    0         2       132     0      1.2
# 300   68    1   2     144   193    1         2       141     0      3.4
# 301   57    1   2     130   131    0         2       115     1      1.2
# 302   57    0   3     130   236    0         1       174     0      0.0
#
#      slope  ca  thall  target
# 0        1   0      1       1
# ...

# %% [markdown]
# ## Handling and Removing Outliers

# %%
#Q1 = data.quantile(0.25)
#Q3 = data.quantile(0.75)
#IQR = Q3 - Q1
#print(IQR)

# %%
#data = data[~((data < (Q1 - 1.5 * IQR))|(data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
data.shape
# Out:
# (303, 14)

# %%
#data.head

# %% [markdown]
# ## Preprocessing

# %%
# check the class balance after removing outliers

Target = data['target'] # target variable
class_counts = data['target'].value_counts()
print(class_counts)

plt.figure(figsize=(8,6))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Class balance check')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64
# Text(0, 0.5, 'Count')

# %%
# separate target from other features

features = data.drop(columns=['target'])
Target = data['target']

# data splitting
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, Target, test_size=0.2, random_state=42)

# check the shape of the test and train parameters
print('Original Data shape', features.shape)
print('The shape of X_train is:', X_train.shape)
print('The shape of X_test is:', X_test.shape)
print('The shape of y_train is:', y_train.shape)
print('The shape of y_test is:', y_test.shape)
# Out:
# Original Data shape (303, 13)
# The shape of X_train is: (242, 13)
# The shape of X_test is: (61, 13)
# The shape of y_train is: (242,)
# The shape of y_test is: (61,)

# %% [markdown]
# ### Data Standardisation/Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# Fit scaler on training data
scaler = MinMaxScaler()
# Transform training data
X_train = scaler.fit_transform(X_train)

# Transform testing data
X_test= scaler.transform(X_test)

print(X_train.shape)
print(X_test.shape)
# Out:
# (242, 13)
# (61, 13)

# %% [markdown]
# ### FEATURE SELECTION WITH PCA

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

# Apply PCA
pca = PCA(13)


X_train = pca.fit_transform(X_train)

# Individual component variance
ind_var = pca.explained_variance_

# Cumulative variance
cum_var_ratio = np.cumsum(pca.explained_variance_ratio_)

# Plot individual component variance
plt.figure()
plt.bar(range(1, len(ind_var) + 1), ind_var, alpha=0.7)
plt.xlabel('Pri. Component')
plt.ylabel('Var. Explained')
plt.title('Individual Component Var.')
plt.show()

# Plot cumulative variance explained
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(cum_var_ratio) + 1), cum_var_ratio, marker='o', 
         linestyle='--', color='r')
plt.xlabel('No. of PCs')
plt.ylabel('Cumulativ Var. Explained')
plt.title('Cumulative Var. Explained by PCs')
plt.grid()
plt.show()

X_test = pca.transform(X_test)

#------------------------------------

# %% [markdown]
# ### K NEAREST NEIGHBORS (KNN) ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
knn_train_accuracy = []
knn_test_accuracy = []


settings = range(1,10)
for n in settings:
    
    #building the model
    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(X_train, y_train)
    
    #append training and generalisation accuracy
    knn_train_accuracy.append(knn.score(X_train, y_train))
    knn_test_accuracy.append(knn.score(X_test, y_test))
    
    #plotting confusion matrix for each n_neigbhour parameter
    predicted = knn.predict(X_test)
    confusion_matrix = metrics.confusion_matrix(y_test, predicted)
    # Plot
    plt.figure()  
    met = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])
    met.plot()
    plt.title(f'Confusion Matrix {n} Neighbours')
    plt.show()

plt.plot(settings, knn_train_accuracy, label = 'Train Accuracy')
plt.plot(settings, knn_test_accuracy, label = 'Test Accuracy')
plt.ylabel('Acuracy'),
plt.xlabel('n_neighbors')
plt.grid()
plt.legend()

#print(knn_train_accuracy)
print(knn_test_accuracy)
# Out:
# [0.8360655737704918, 0.819672131147541, 0.7868852459016393, 0.7540983606557377, 0.7868852459016393, 0.8032786885245902, 0.7868852459016393, 0.8032786885245902, 0.8032786885245902]

# %% [markdown]
# ### Evaluation: Precision, Specificity and Sensitivity for KNN

# %%
from sklearn.metrics import classification_report

#y_pred=NB_clsifr.predict(X_test)
print(classification_report(y_test, predicted))

# specificity
TN,FP,FN,TP = (metrics.confusion_matrix(y_test, predicted)).ravel()
specificity= TN/(TN+FP)
print('knn specificity is', specificity)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81        29
#            1       0.86      0.75      0.80        32
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.81      0.80        61
# weighted avg       0.81      0.80      0.80        61
#
# knn specificity is 0.8620689655172413

# %% [markdown]
# ### RANDOM FOREST ALGORITHM (RF)

# %%
from sklearn.ensemble import RandomForestClassifier

train_accuracy = []
test_accuracy = []


settings = range(1,10)
for n in settings:
    
    #building the model
    RF = RandomForestClassifier(n_estimators=n, max_features='sqrt', random_state=42)
    RF.fit(X_train, y_train)
    
    #append training and generalisation accuracy
    train_accuracy.append(RF.score(X_train, y_train))
    test_accuracy.append(RF.score(X_test, y_test))
    
    #plotting confusion matrix for each n_neigbhour parameter
    predicted = RF.predict(X_test)
    confusion_matrix = metrics.confusion_matrix(y_test, predicted)
    # Plot
    plt.figure()  
    met = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])
    met.plot()
    plt.title(f'Confusion Matrix {n}')
    plt.show()

plt.plot(settings, train_accuracy, label = 'Train Accuracy')
plt.plot(settings, test_accuracy, label = 'Test Accuracy')
plt.ylabel('Accuracy'),
plt.xlabel('n_estimators')
plt.grid()
plt.legend()

#print(train_accuracy)
print(test_accuracy)
# Out:
# [0.7049180327868853, 0.6721311475409836, 0.819672131147541, 0.7704918032786885, 0.819672131147541, 0.7377049180327869, 0.8524590163934426, 0.819672131147541, 0.8360655737704918]

# %% [markdown]
# ### Evaluation: Precision, Specificity and Sensitivity for Random Forest

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predicted))

# specificity
TN,FP,FN,TP = (metrics.confusion_matrix(y_test, predicted)).ravel()
specificity= TN/(TN+FP)
print('RF specificity is', specificity)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84        29
#            1       0.92      0.75      0.83        32
#
#     accuracy                           0.84        61
#    macro avg       0.85      0.84      0.84        61
# weighted avg       0.85      0.84      0.84        61
#
# RF specificity is 0.9310344827586207

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
import sklearn.svm as sv 

# SVM classification
clsfi=sv.SVC(kernel='rbf')
clsfi.fit(X_train,y_train)
Acc_tr=clsfi.score(X_train,y_train)
Acc_tes=clsfi.score(X_test,y_test)
print('Train Accuracy=',Acc_tr)
print('Test Accuracy=',Acc_tes)
# Out:
# Train Accuracy= 0.9008264462809917
# Test Accuracy= 0.8852459016393442

# %%
# SVM classification with different kernels
Acc_tr=[]
Acc_tes=[]
kernel=[]

for i in ['poly', 'linear', 'sigmoid', 'rbf']:
    clsfi=sv.SVC(kernel=i, degree=2)
    clsfi.fit(X_train,y_train)
    Acc_tr.append(clsfi.score(X_train,y_train))
    Acc_tes.append(clsfi.score(X_test,y_test))
    kernel.append(i)
print(Acc_tr)
print(Acc_tes)    

plt.figure()
plt.plot(Acc_tr,label='Train', marker='o')
plt.plot(Acc_tes,label='Test', marker='o')
plt.xticks([0, 1, 2, 3], kernel)
plt.xlabel('kernel')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# [0.78099173553719, 0.8305785123966942, 0.7520661157024794, 0.9008264462809917]
# [0.7704918032786885, 0.8688524590163934, 0.8032786885245902, 0.8852459016393442]

# %%
# Confusion matrix for SVM
from sklearn.metrics import confusion_matrix
y_pred = clsfi.predict(X_test)
#print(y_pred)
confusion_matrix=confusion_matrix(y_test, y_pred)
plt.figure()  
met = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])
met.plot()
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### PRECISION, SPECIFICITY AND SENSITIVITY FOR SVM

# %%
print(classification_report(y_test,y_pred))

# specificity
TN,FP,FN,TP = (metrics.confusion_matrix(y_test, y_pred)).ravel()
specificity= TN/(TN+FP)
print('SVM specificity is', specificity)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.89        29
#            1       0.93      0.84      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.89      0.89        61
# weighted avg       0.89      0.89      0.89        61
#
# SVM specificity is 0.9310344827586207

# %% [markdown]
# ### Naive Bayes Algorithm

# %%
from sklearn.naive_bayes import GaussianNB


NB_clsifr=GaussianNB()
NB_clsifr.fit(X_train,y_train)
Acc_tr=NB_clsifr.score(X_train,y_train)
Acc_tes=NB_clsifr.score(X_test,y_test)
print('Train Accuracy=',Acc_tr)
print('Test Accuracy=',Acc_tes)


# Create a list of settings for the x-axis, e.g., different models or iterations
#settings = ['Naive Bayes']
# Plot the accuracies
plt.figure(figsize=(10, 6))
plt.plot(Acc_tr, marker='o', linestyle='-', color='b', label='Train Accuracy')
plt.plot(Acc_tes, marker='o', linestyle='-', color='r', label='Test Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Model')
plt.title('Training and Testing Accuracy of Gaussian Naive Bayes Classifier')
plt.grid(True)
plt.legend()
plt.ylim(0, 1)

# Add annotations
for i, acc in enumerate([Acc_tr]):
    plt.text(i, acc, f'{acc:.2f}', ha='center', va='bottom', fontsize=12, color='black')
for i, acc in enumerate([Acc_tes]):
    plt.text(i, acc, f'{acc:.2f}', ha='center', va='bottom', fontsize=12, color='black')

plt.show()
#OR
#NB_clsifr=GaussianNB()
#NB_clsifr.fit(X_train,y_train)

#y_pred = NB_clsifr.predict(X_test)

#print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Train Accuracy= 0.8099173553719008
# Test Accuracy= 0.8032786885245902

# %%
y_pred=NB_clsifr.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81        29
#            1       0.88      0.72      0.79        32
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.81      0.80        61
# weighted avg       0.82      0.80      0.80        61

# %%
y_pred = NB_clsifr.predict(X_test)
#print(y_pred)
confusion_matrix=metrics.confusion_matrix(y_test, y_pred)
plt.figure()  
met = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])
met.plot()
plt.title('Confusion Matrix')
plt.show()

# %%
# specificity
TN,FP,FN,TP = (metrics.confusion_matrix(y_test, y_pred)).ravel()
specificity= TN/(TN+FP)
print('NB specificity is', specificity)
# Out:
# NB specificity is 0.896551724137931

# %% [markdown]
# ### Ensemble learning using voting classifier

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

RF = RandomForestClassifier(random_state=42)
KNN = KNeighborsClassifier()
NB = GaussianNB()
SVM = SVC(kernel = 'rbf', random_state=42)

vc = (VotingClassifier(estimators=[("RF", RF),("KNN",KNN),("NB",NB),("SVM",SVM)]))

vc.fit(X_train, y_train)

y_train_pred = vc.predict(X_train)

print(accuracy_score(y_train, y_train_pred))
# Predict the test labels
y_test_pred = vc.predict(X_test)

# Calculate the test accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)

y_test_pred=vc.predict(X_test)
print(classification_report(y_test,y_test_pred))
# Out:
# 0.9008264462809917
# Test Accuracy: 0.8524590163934426
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86        29
#            1       0.93      0.78      0.85        32
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.86      0.85        61
# weighted avg       0.86      0.85      0.85        61

# %% [markdown]
# ### Ensemble learning using the best two RF and SVM

# %%
RF = RandomForestClassifier(random_state=42)
SVM = SVC(kernel = 'rbf', random_state=42)

vc = (VotingClassifier(estimators=[("RF", RF),("SVM",SVM)]))

vc.fit(X_train, y_train)

y_train_pred = vc.predict(X_train)

print(accuracy_score(y_train, y_train_pred))

# Predict the test labels
y_test_pred = vc.predict(X_test)

# Calculate the test accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)


y_test_pred=vc.predict(X_test)
print(classification_report(y_test,y_test_pred))
# Out:
# 0.9462809917355371
# Test Accuracy: 0.8360655737704918
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84        29
#            1       0.92      0.75      0.83        32
#
#     accuracy                           0.84        61
#    macro avg       0.85      0.84      0.84        61
# weighted avg       0.85      0.84      0.84        61

# %% [markdown]
# ### Ensemble learning using the best three RF, SVM and NB

# %%
RF = RandomForestClassifier(random_state=42)
NB = GaussianNB()
SVM = SVC(random_state=42)

vc = (VotingClassifier(estimators=[("RF", RF),("NB",NB),("SVM",SVM)]))

vc.fit(X_train, y_train)

y_train_pred = vc.predict(X_train)

print(accuracy_score(y_train, y_train_pred))

# Predict the test labels
y_test_pred = vc.predict(X_test)

# Calculate the test accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# 0.9173553719008265
# Test Accuracy: 0.8524590163934426

# %%
# Ensemble learning with KNN and RF

RF = RandomForestClassifier(random_state=42)
KNN = KNeighborsClassifier()

vc = (VotingClassifier(estimators=[("RF", RF),("KNN",KNN)]))

vc.fit(X_train, y_train)

y_train_pred = vc.predict(X_train)

print(accuracy_score(y_train, y_train_pred))
# Predict the test labels
y_test_pred = vc.predict(X_test)

# Calculate the test accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)
print('.................................................')

# Ensemble learning with KNN and NB
KNN = KNeighborsClassifier()
NB = GaussianNB()

vc = (VotingClassifier(estimators=[("RF", RF),("KNN",KNN),("NB",NB),("SVM",SVM)]))

vc.fit(X_train, y_train)

y_train_pred = vc.predict(X_train)

print(accuracy_score(y_train, y_train_pred))
# Predict the test labels
y_test_pred = vc.predict(X_test)

# Calculate the test accuracy
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# 0.9214876033057852
# Test Accuracy: 0.8360655737704918
# .................................................
# 0.9008264462809917
# Test Accuracy: 0.8524590163934426

# %% [markdown]
# ### Hyperparameter tunning on the best models SVM AND Random forest

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer, f1_score

# %%
# Random Search for Random forest

# %%
param_grid = { 
    'n_estimators': [25, 50, 100, 150], 
    'max_features': ['sqrt', 'log2', None], 
    'max_depth': [3, 6, 9], 
    'max_leaf_nodes': [3, 6, 9], 
} 

random_search = RandomizedSearchCV(RandomForestClassifier(), 
                                   param_grid) 
random_search.fit(X_train, y_train)

# Print the best hyperparameters and best accuracy score for Random Search
print("Best Parameters:", random_search.best_params_)
print("Best Score:", random_search.best_score_)

best_rf_random = random_search.best_estimator_
print(best_rf_random)
# Out:
# Best Parameters: {'n_estimators': 150, 'max_leaf_nodes': 9, 'max_features': 'sqrt', 'max_depth': 3}
# Best Score: 0.8018707482993197
# RandomForestClassifier(max_depth=3, max_leaf_nodes=9, n_estimators=150)

# %%
model_random = RandomForestClassifier(max_depth=3, 
                                      max_features='sqrt', 
                                      max_leaf_nodes=9, 
                                      n_estimators=150) 
model_random.fit(X_train, y_train) 
y_pred_rand = model_random.predict(X_test) 

test_accuracy_random = best_rf_random.score(X_test, y_test)
print("Test Accuracy (Random Search): {:.2f}%".format(test_accuracy_random * 100))

print(classification_report(y_pred_rand, y_test))
# Out:
# Test Accuracy (Random Search): 83.61%
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86        34
#            1       0.78      0.93      0.85        27
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.86      0.85        61
# weighted avg       0.86      0.85      0.85        61

# %%
# Random Search for SVM

# Define the parameter distributions for Random Search
param_dist = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']
             } 
 
# Create an SVM classifier
svm = sv.SVC()

# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(svm, param_distributions=param_dist, n_iter=25, 
                                   scoring='accuracy', n_jobs=-1, cv=5, random_state=42)
 
# Fit the RandomizedSearchCV object to the training data
random_search.fit(X_train, y_train)
 
# Print the best hyperparameters and best accuracy score for Random Search
print("Best Parameters:", random_search.best_params_)
print("Best Score:", random_search.best_score_)
 
# Evaluate the best models on the test set
best_svm_random = random_search.best_estimator_
test_accuracy_random = best_svm_random.score(X_test, y_test)
 
print("Test Accuracy (Random Search): {:.2f}%".format(test_accuracy_random * 100))
print("Tunned SVM Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'kernel': 'rbf', 'gamma': 0.01, 'C': 100}
# Best Score: 0.8098639455782314
# Test Accuracy (Random Search): 86.89%
# Tunned SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81        29
#            1       0.88      0.72      0.79        32
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.81      0.80        61
# weighted avg       0.82      0.80      0.80        61

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import sklearn.svm as sv
from sklearn.naive_bayes import GaussianNB


import numpy as np
print('Cross Validation scores for Random Forest: ', cross_val_score(RandomForestClassifier(n_estimators=5, max_features='sqrt', random_state=52),features,Target, cv = 5))
RMean_Score = np.mean(cross_val_score(RandomForestClassifier(n_estimators=6, max_features='sqrt', random_state=3),features,Target))
print('Average Random Forest Cross Validation Score', RMean_Score)
print("=================================================================================================")
print('Cross Validation scores for SVM', cross_val_score(sv.SVC(kernel='rbf'),features,Target, cv = 5))
SMean_Score = np.mean(cross_val_score(sv.SVC(kernel='rbf'),features,Target))
print('Average SVM Cross Validation Score',SMean_Score)
print("=================================================================================================")
print('Cross Validation scores for KNN', cross_val_score(KNeighborsClassifier(n_neighbors=9),features,Target, cv = 5))
KMean_Score = np.mean(cross_val_score(KNeighborsClassifier(n_neighbors=5),features,Target))
print('Average KNN Cross Validation Score',KMean_Score)
print("=================================================================================================")
print('Cross Validation scores for NB', cross_val_score(GaussianNB(),features,Target, cv = 5))
NMean_Score = np.mean(cross_val_score(GaussianNB(),features,Target))
print('Average NB Cross Validation Score',NMean_Score)
# Out:
# Cross Validation scores for Random Forest:  [0.78688525 0.8852459  0.75409836 0.73333333 0.81666667]
# Average Random Forest Cross Validation Score 0.7524043715846995
# ...
# Cross Validation scores for SVM [0.60655738 0.60655738 0.73770492 0.68333333 0.58333333]
# Average SVM Cross Validation Score 0.6434972677595628
# ...
# Cross Validation scores for KNN [0.59016393 0.6557377  0.60655738 0.71666667 0.58333333]
# Average KNN Cross Validation Score 0.643879781420765
# ...
# Cross Validation scores for NB [0.81967213 0.91803279 0.75409836 0.86666667 0.78333333]
# Average NB Cross Validation Score 0.828360655737705

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from scipy.stats import randint, uniform

# Define the parameter distributions for svc

param_dist_svc = {
    'C': uniform(0.1, 100),
    'gamma': uniform(0.001, 1),
    'kernel': ['rbf', 'poly', 'sigmoid']
}

# Choose the model and parameter distribution
model = SVC()  # Replace with SVC() or KNeighborsClassifier() as needed
param_dist = param_dist_svc  # Replace with param_dist_svc or param_dist_knn as needed

# Perform Random Search with Cross-Validation
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, 
                                   n_iter=100, cv=5, n_jobs=-1, verbose=2, random_state=42)
random_search.fit(X_train, y_train)

# Best parameters and score
best_params = random_search.best_params_
best_score = random_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
# Evaluate on the test set
best_model = random_search.best_estimator_
test_score = best_model.score(X_test, y_test)
print("Test Score of Best Model:", test_score)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best Parameters: {'C': 77.22703466859457, 'gamma': 0.07504465173409036, 'kernel': 'sigmoid'}
# Best Cross-Validation Score: 0.826530612244898
# Test Score of Best Model: 0.8524590163934426

# %%
# Assuming best_model is your final trained model from Random Search

# Evaluate on the training set
train_score = best_model.score(X_train, y_train)
print("Training Score of Best Model:", train_score)

# Evaluate on the test set
test_score = best_model.score(X_test, y_test)
print("Test Score of Best Model:", test_score)

# Cross-validation score (already known)
cv_score = random_search.best_score_
print("Cross-Validation Score of Best Model:", cv_score)

# Check if the scores are consistent
if abs(train_score - cv_score) < 0.05 and abs(test_score - cv_score) < 0.05:
    print("The model is well-tuned and generalizes well.")
else:
    print("There might be some overfitting or data issues to investigate.")
# Out:
# Training Score of Best Model: 0.8553719008264463
# Test Score of Best Model: 0.8524590163934426
# Cross-Validation Score of Best Model: 0.826530612244898
# The model is well-tuned and generalizes well.

# %%
# Define the parameter distributions for knn

param_dist_knn = {
    'n_neighbors': randint(3, 20),
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

# Choose the model and parameter distribution
model = KNeighborsClassifier()  # Replace with SVC() or KNeighborsClassifier() as needed
param_dist = param_dist_knn  # Replace with param_dist_svc or param_dist_knn as needed

# Perform Random Search with Cross-Validation
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, 
                                   n_iter=100, cv=5, n_jobs=-1, verbose=2, random_state=42)
random_search.fit(X_train, y_train)

# Best parameters and score
best_params = random_search.best_params_
best_score = random_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)

# Evaluate on the test set
best_model = random_search.best_estimator_
test_score = best_model.score(X_test, y_test)
print("Test Score of Best Model:", test_score)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best Parameters: {'n_neighbors': 13, 'p': 2, 'weights': 'distance'}
# Best Cross-Validation Score: 0.7935374149659864
# Test Score of Best Model: 0.8032786885245902

# %%
# Assuming best_model is your final trained model from Random Search

# Evaluate on the training set
train_score = best_model.score(X_train, y_train)
print("Training Score of Best Model:", train_score)

# Evaluate on the test set
test_score = best_model.score(X_test, y_test)
print("Test Score of Best Model:", test_score)

# Cross-validation score (already known)
cv_score = random_search.best_score_
print("Cross-Validation Score of Best Model:", cv_score)

# Check if the scores are consistent
if abs(train_score - cv_score) < 0.05 and abs(test_score - cv_score) < 0.05:
    print("The model is well-tuned and generalizes well.")
else:
    print("There might be some overfitting or data issues to investigate.")
# Out:
# Training Score of Best Model: 1.0
# Test Score of Best Model: 0.8032786885245902
# Cross-Validation Score of Best Model: 0.7935374149659864
# There might be some overfitting or data issues to investigate.

# %%
# Define the parameter distributions for rf
param_dist_rf = {
    'n_estimators': randint(100, 500),
    'max_depth': [None] + list(range(10, 50, 10)),
    'min_samples_split': randint(2, 11),
    'min_samples_leaf': randint(1, 5),
    'bootstrap': [True, False]
}

# Choose the model and parameter distribution
model = RandomForestClassifier()  # Replace with SVC() or KNeighborsClassifier() as needed
param_dist = param_dist_rf  # Replace with param_dist_svc or param_dist_knn as needed

# Perform Random Search with Cross-Validation
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, 
                                   n_iter=100, cv=5, n_jobs=-1, verbose=2, random_state=42)
random_search.fit(X_train, y_train)

# Best parameters and score
best_params = random_search.best_params_
best_score = random_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)

# Evaluate on the test set
best_model = random_search.best_estimator_
test_score = best_model.score(X_test, y_test)
print("Test Score of Best Model:", test_score)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 202}
# Best Cross-Validation Score: 0.8100340136054422
# Test Score of Best Model: 0.819672131147541

# %%
# Assuming best_model is your final trained model from Random Search

# Evaluate on the training set
train_score = best_model.score(X_train, y_train)
print("Training Score of Best Model:", train_score)

# Evaluate on the test set
test_score = best_model.score(X_test, y_test)
print("Test Score of Best Model:", test_score)

# Cross-validation score (already known)
cv_score = random_search.best_score_
print("Cross-Validation Score of Best Model:", cv_score)

# Check if the scores are consistent
if abs(train_score - cv_score) < 0.05 and abs(test_score - cv_score) < 0.05:
    print("The model is well-tuned and generalizes well.")
else:
    print("There might be some overfitting or data issues to investigate.")
# Out:
# Training Score of Best Model: 0.9504132231404959
# Test Score of Best Model: 0.819672131147541
# Cross-Validation Score of Best Model: 0.8100340136054422
# There might be some overfitting or data issues to investigate.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.naive_bayes import GaussianNB
from scipy.stats import loguniform

# Define the parameter distribution for GaussianNB
param_dist_nb = {
    'var_smoothing': loguniform(1e-11, 1e-9)
}

# Choose the model
model = GaussianNB()

# Perform Random Search with Cross-Validation
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist_nb, 
                                   n_iter=100, cv=5, n_jobs=-1, verbose=2, random_state=42)
random_search.fit(X_train, y_train)

# Best parameters and score
best_params = random_search.best_params_
best_score = random_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)

# Evaluate on the test set
best_model = random_search.best_estimator_
test_score = best_model.score(X_test, y_test)
print("Test Score of Best Model:", test_score)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best Parameters: {'var_smoothing': 5.611516415334504e-11}
# Best Cross-Validation Score: 0.76828231292517
# Test Score of Best Model: 0.8032786885245902

# %%
# Evaluate on the training set
train_score = best_model.score(X_train, y_train)
print("Training Score of Best Model:", train_score)

# Cross-validation score (already known)
cv_score = random_search.best_score_
print("Cross-Validation Score of Best Model:", cv_score)

# Check if the scores are consistent
if abs(train_score - cv_score) < 0.05 and abs(test_score - cv_score) < 0.05:
    print("The model is well-tuned and generalizes well.")
else:
    print("There might be some overfitting or data issues to investigate.")
# Out:
# Training Score of Best Model: 0.8099173553719008
# Cross-Validation Score of Best Model: 0.76828231292517
# The model is well-tuned and generalizes well.
